# %%
import pandas as pd
import re
import itertools
import numpy as np
from uti import DataLoader, Logger
from Database import tpc_scanner, rc_scanner, rating_scanner

DL = DataLoader()
logger = Logger()
# Out:
# C:\Users\JayYang\Platform\Citi\Path\settings.py C:\Users\JayYang\Platform\Citi\Path\settings.py
# Base path C:/Users/JayYang
# Platform path C:/Users/JayYang/Platform
# Onedrive directory: C:/Users/JayYang/OneDrive - Alpha Sherpa Capital
# Daily path C:/Users/JayYang/OneDrive - Alpha Sherpa Capital/Daily
# Database path C:/Users/JayYang/OneDrive - Alpha Sherpa Capital/Database/Citi
# 2022-05-18 18:19:12,477 P[20764] [MainThread 4180] Error: no proxy address identified.
# Check if Eikon Desktop or Eikon API Proxy is running.
# 2022-05-18 18:19:12,478 P[20764] [MainThread 4180] Error on handshake url http://127.0.0.1:None/api/handshake : UnsupportedProtocol("Request URL is missing an 'http://' or 'https://' protocol.")
# 2022-05-18 18:19:12,478 P[20764] [MainThread 4180] Error on handshake url http://127.0.0.1:None/api/handshake : UnsupportedProtocol("Request URL is missing an 'http://' or 'https://' protocol.")
# ...

# %%
from Database import GSPriceDf

# %%
GSP = GSPriceDf()

# %%
GSP.get_valid_tickers_dict()

# %%
GSP._valid_tickers_dict['ticker']
# Out:
# {'ADCB.AD': 'ADCB.AD',
#  'ALDAR.AD': 'ALDAR.AD',
#  'ARMX.DU': 'ARMX.DU',
#  'AIRA.DU': 'AIRA.DU',
#  'ADNO.AD': 'ADNOCDIST.AD',
#  'ADNOCDRILL.AD': 'ADNOCDRILL.AD',
#  'DISB.DU': 'DISB.DU',
#  'DFM.DU': 'DFM.DU',
#  'DAMAC.DU': 'DAMAC.DU',
#  'DXBE.DU': 'DXBE.DU',
#  'DPW.DI': 'DPW.DI',
#  'EMAR.DU': 'EMAR.DU',
#  'ETEL.AD': 'ETISALAT.AD',
#  'ENBD.DU': 'ENBD.DU',
#  'EMAA.DU': 'EMAA.DU',
#  'EMAARDEV.DU': 'EMAARDEV.DU',
#  'FERTIGLOBE.AD': 'FERTIGLOBE.AD',
#  'FAB.AD': 'FAB.AD',
#  'SLB': 'SLB',
#  'BMA.BA': 'BMA.BA',
#  'SUPV.BA': 'SUPV.BA',
#  'BBAR.BA': 'BBAR.BA',
#  'GGAL.BA': 'GGAL.BA',
#  'STRV.VI': 'STRV.VI',
#  'AMAV.VI': 'AMAV.VI',
#  'FACC.VI': 'FACC.VI',
#  'VIEV.VI': 'VIEV.VI',
#  'RBIV.VI': 'RBIV.VI',
#  'ABGV.VI': 'ABGV.VI',
#  'CAIV.VI': 'CAIV.VI',
#  'LENV.VI': 'LENV.VI',
#  'ERST.VI': 'ERST.VI',
#  'TELA.VI': 'TELA.VI',
#  'ANDR.VI': 'ANDR.VI',
#  'EVNV.VI': 'EVNV.VI',
#  'OMVV.VI': 'OMVV.VI',
#  'VERB.VI': 'VERB.VI',
#  'PALF.VI': 'PALF.VI',
# ...

# %%
summary_list = ["""We see scope for material re-rating of the Centrica shares at 1H results on July 28th. In our view, the resumption of dividends, followed by a potential debt and/or equity buyback in 2H should lead to meaningful earnings accretion and re-rating of the shares. This catalyst, combined with a continued supportive regulatory environment from Ofgem on the energy price cap, should help to further support the share price. We reiterate our Buy, PT 105p/share and open a 3-months catalyst watch for the shares in the run up to its 1H results."""]
summary_list = ["""Citi's Take - IMP reported a 6.2% y-o-y decline in gross refined platinum production to 331,000 ounces (Pt) for the quarter ended March 31 2017 (3Q17). This is 5.4% below our 350,000 ounce expectations. The decline was mainly as a result of (i) community disruptions which affected production at Marula and Two rivers, and (ii) release of material form processing inventory at Zimplats during the previous comparable quarter. Lease production up 13% - 3Q17 production was up 12.7% y-o-y at 160,000 ounces vs CitiE of 164,000 ounces. The increase was due to a release of material that was locked up in processing during 1H17. Production at the Lease continued to be impacted by repair work following the underground fire at 14 shaft that occurred in January 2016. The company expects full production from June 2017. Zimplats down 25.8% from high base - Platinum production in matte for Zimplats decreased 25.8% y-o-y to 66,000 ounces, from a very high 3Q16 base (89,000). The higher base was due to the release of stockpiled materials in 3Q16. Cost outlook increased - IMP increased its FY17 unit cost guidance from R22,200 to 22,600/Pt oz due to (i) lower expected production form Marula, and (ii) weaker rand/dollar exchange rate expectations. We see this as disappointing, given (i) the already high base, and (ii) our view that concrete enough actions are note being taken to sustainably move IMP back down to cost curve (refer: Years of sub-optimal performance now leave low-hanging fruit). Implications - Despite yet another weak update, we maintain our Buy rating. We believe years of suboptimal performance now leave a low hanging fruit for incoming CEO, Mr. Nico Muller, who started on April 3, 2017. Maintain Buy, TP R60."""]
rating_scanner(summary_list)
# Out:
# ['buy']

# %%
import re

# %%
summary_list = ['We downgrade Experian to Neutral as we believe cyclical headwinds are likely to make it difficult for the North American Data business to deliver consensus’ FY23E organic growth of 8.2%. In an environment in which US housing transactions reduce year-over-year, we think 4% is more reasonable. With our group adjusted PBT of $1,707m c.2% below Visible Alpha consensus at $1,743m, we do not believe that consensus earnings estimates can continue to rise, driving the downgrade. We continue to view the company’s cash generative nature and strong track record of organic growth as attractive, and see upside to FY23E consensus in the Latin American business. ']
dg_pattern = re.compile(r'\bdowngrad[a-z]{1,3} [a-z0-9]+ to(?<!%) ([a-z]{1,7})(?<!%)|'
                        r'\downgrad[a-z]{1,3} to ([a-z]{1,7})(?<!%)', flags=re.I)
result = dg_pattern.findall(summary_list[0].lower())
result

# %%
k = '\nwe downgrade advantech to sell (from neutral) after the company gave a weaker than expected guidance and declining\nbb ratio. despite attributable to supply issues the falloff partly implies advanced booking before price adjustments\nand weakening macro outlook. nevertheless we notice the valuation multiple has diverged from what pmi indicated\nimplying downside risks from mispricing of slowdown. we expect the share price would have to go down to reflect the\ncyclical slowdown in the next 12 months. declining bb ratio or order cancellation could be negative catalysts.\n\n'

# %%
senti = DL.loadDB('Citi sentiment.csv')
# Out:
# 16:32:40 Loading C:/Users/JayYang/OneDrive - Alpha Sherpa Capital/Database/Citi\Citi sentiment.csv

# %%
# Scan through all the reports, not necessarily Rating Change
# RC_mask = senti['Report Types'].fillna('').str.contains('Rating Change') & ~senti['Tickers'].fillna('').str.contains(',') & senti['rating_new'].isna()
# RC_mask = ~senti['Tickers'].fillna('').str.contains(',') & senti['rating_new'].isna()
RC_mask = ~senti['Tickers'].fillna('').str.contains(',') & ~senti['Report Types'].fillna('').str.contains('Rating Change')

# %%
rating_scanner([senti.loc[RC_mask, 'Summary'].iloc[0]])
# Out:
# ['buy']

# %%
senti.loc[RC_mask, 'Summary']
# Out:
# 0        Closer inspection of Bidvest's interim results...
# 1        Regulator approves offer of 25% of Vodacom Tan...
# 2        We view the FY16 result as a strong underlying...
# 4        Citi's Take - Standard Bank reported diluted H...
# 5        Implied value analysis - Given that Exxaro sha...
#                                ...
# 67360    IOCL's 4Q EBITDA at Rs116bn (+18% qoq) was sli...
# 67362    HEIG will be holding a Capital Market Day on 2...
# 67363    We revise our forecasts following the C1Q22 re...
# 67364    BT reported a broadly in line Q4 results. Most...
# 67366    Citi hosted Entain's CFO and Deputy CEO Rob Wo...
# Name: Summary, Length: 47091, dtype: object

# %%
ratings_list = rating_scanner(senti.loc[RC_mask, 'Summary'])

# %%
SIA defers S$4.4bn aircraft capex (-18%) over FY20/21-24/25 - According to SGX filing Feb 9th, SIA reached agreements with Airbus and Boeing to spread out aircraft deliveries over a longer period than originally contracted. No cancellation is made. Total aggregate savings are S$4.4bn (-18%) in combined over FY20/21-24/25 where reductions are deepest during FY20/21-21/22 at S$3.9bn (-35%). These help preserve cash outflows in the near term and potentially reduce pressure in ramping back capacity. It is also converting 14 Boeing 787-10 on existing orders into 11 additional Boeing 777-9. Strategically strengthening Singapore's hub status - (i) Against global widebody trends of airlines moving toward smaller aircraft such as Emirates looking to swap up to a third of its 777X orders for smaller 787 (Bloomberg Feb 3rd), SIA is doing the opposite. Based on Boeing's website, 777-9 offers c15% additional range and c27% more seating capacity of 787-10. 777-9 is relatively more optimal for long-haul, i.e., Singapore-Western Europe, and should offer lower unit costs assuming SIA can fill seats. (ii) No order cancellation compared to its neighboring mid / long-haul airlines such as AirAsia X seeking to cancel majority of orders under debt restructuring plans (ChannelNewsAsia Dec 22nd 2020) or Thai Airways fully retiring A380, A330 and 747 (Simple Flying Feb 9th). A combination of (i) and (ii) reinforces our view that Singapore Changi's hub status will emerge stronger into a post-Covid world. Limited rationale of SIA calling back 1st tranche of MCB - Assuming 60% of capex is outright purchase, SIA's FY20/21-24/25 would average cS$2.4bn pa. The amount is in-line with pre-Covid's annual EBITDA run rate of cS$2.4bn. Based on DecQ-20 DE ratio of 0.78x and our expectation that SIA will continue to make losses in FY21/22E, we believe it is unlikely that SIA will call back 1st tranche of convertible bonds in the foreseeable future. Implications to SIA stock - We agree with SIA's decision in orders' deferral rather than cancellation, which we see as an optimal growth strategy considering Temasek's financial supports. However, its revised capex plans convince us that investors should take dilution effects from 1st tranche of mandatory convertible bonds into account which we have already included in our fully diluted share base. We continue to see SIA's 1.2x FY20/21E PBV as expensive and maintain our Sell rating with S$3.9 TP. We reiterate our Buy rating on SATS with S$4.7 TP as the key beneficiary of Singapore Changi's likely strengthening hub status.
# Out:
# ['buy',
#  '',
#  '',
#  '',
#  'buy',
#  '',
#  'neutral',
#  'sell',
#  '',
#  'buy',
#  '',
#  '',
#  'buy',
#  'neutral',
#  'neutral',
#  'neutral',
#  '',
#  '',
#  'buy',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'buy',
#  'buy',
#  '',
#  'buy',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'buy',
#  '',
#  '',
#  '',
#  'buy',
#  '',
#  '',
#  "['buy', 'sell']",
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'neutral',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'neutral',
#  '',
#  '',
#  '',
#  '',
#  'neutral',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'neutral',
#  'buy',
#  'buy',
#  '',
#  '',
#  'buy',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'buy',
#  '',
#  '',
#  '',
#  '',
#  'buy',
#  '',
#  'buy',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'sell',
#  '',
#  '',
#  '',
#  '',
#  'neutral',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'buy',
#  '',
#  '',
#  '',
#  'buy',
#  '',
#  '',
#  '',
# ...

# %%
senti.loc[RC_mask,'rating_new'] = ratings_list

# %%
DL.toDB(senti, 'Citi sentiment tocheck.csv')

# %%
rc_list, rc_list_real = rc_scanner(senti[RC_mask].reset_index()['Summary'])
print(np.array(rc_list))
senti.loc[RC_mask, 'RC_upgrade'] = np.array(rc_list)[:, 0]
senti.loc[RC_mask, 'RC_downgrade'] = np.array(rc_list)[:, 1]
senti.loc[RC_mask, 'rating_new'] = rc_list_real
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# we think current political events and rating agency downgrade of sa's sovereign credit rating to sub-ig bring about an opportunity to own this quality high-growth stock on a rare pull-back. in our view the growth story remains intact as customers continue to be attracted by capitec's easy-to-understand and inexpensive bank account. in addition we believe that the credit card (and future funeral insurance product) will add meaningfully to growth over the coming 3 years. we still forecast 20%+ growth over our forecast period even after building in stubbornly high credit losses in fy18e. we feel that the market under-appreciates the number of years of high growth that capitec will enjoy before becoming a nominal gdp proxy like the traditional banks. in our model we adjust our sustainable growth assumption to 10.5% giving us a r832 target price. we upgrade to buy.
# ...

# %%
DL.toDB(senti, 'Citi sentiment tocheck.csv')

# %%
senti.loc[RC_mask, 'rating_new'].value_counts()
# Out:
#            46341
# buy          154
# neutral      137
# sell          12
# Name: rating_new, dtype: int64

# %%
len(senti[senti['Report Types'].fillna('').str.contains('Rating Change')])
# Out:
# 2088

# %%
DL.toDB(senti[senti['Report Types'].fillna('').str.contains('Rating Change')], 'RC_sample.csv')

# %%
k = """
We downgrade Advantech to Sell (from Neutral) after the company gave a weaker than expected guidance and declining
BB ratio. Despite attributable to supply issues, the falloff partly implies advanced booking before price adjustments
and weakening macro outlook. Nevertheless, we notice the valuation multiple has diverged from what PMI indicated,
implying downside risks from mispricing of slowdown. We expect the share price would have to go down to reflect the
cyclical slowdown in the next 12 months. Declining BB ratio or order cancellation could be negative catalysts.

"""

# %%
rc['Summary'].iloc[2]
# Out:
# 'Upgrade to Buy – Chola reported net profit of Rs6.9bn (+184% yoy, +32% qoq), in line with our est., as strong NPA recoveries offset slow operating profit growth (+3% yoy) due to high opex. While partnerships drove a large portion of disbursements in new segments in 4Q, this should fall over time as internal channels develop. We maintain estimates (stay with our 20bps NIM decline in FY23, build slightly higher opex, lower credit cost), keep target price unchanged, but upgrade to Buy after the 13% decline in the stock since our downgrade (vs. Nifty -6%). Currently, 1y forward P/B of 3.7x is 1 std dev above mean (comparable to Nifty). A key risk is a protracted high fuel price environment, which can strain customer cash flows (see Fig 6).'

# %%
rc_list = rc_scanner(rc['Summary'])
# Out:
# []
# []
# []
# []
# [('', 'buy'), ('buy', '')]
# []
# [('', 'buy')]
# []
# [('a', '')]
# []
# [('a', '')]
# []
# []
# [('buy', '')]
# [('join', '')]
# [('sell', '')]
# []
# []
# []
# []
# [('', 'neutral')]
# []
# [('', 'buy'), ('', 'a')]
# []
# []
# [('', 'buy')]
# [('neutral', '')]
# []
# [('neutral', '')]
# []
# [('a', '')]
# []
# []
# []
# []
# [('', 'buy')]
# [('sell', '')]
# []
# []
# []
# []
# []
# [('buy', '')]
# []
# [('a', '')]
# []
# []
# []
# []
# []
# []
# [('neutral', '')]
# []
# []
# [('', 'a')]
# []
# [('neutral', '')]
# [('buy', '')]
# []
# []
# []
# []
# []
# []
# [('', 'a')]
# [('', 'a')]
# [('', 'be')]
# []
# []
# [('buy', '')]
# []
# []
# [('buy', '')]
# []
# []
# []
# [('neutral', '')]
# []
# []
# []
# []
# []
# []
# []
# []
# [('a', '')]
# []
# []
# [('', 'buy')]
# []
# []
# []
# []
# []
# []
# []
# [('sell', '')]
# []
# []
# []
# [('neutral', '')]
# []
# [('', 'a')]
# []
# [('buy', '')]
# [('', 'buy')]
# []
# []
# [('neutral', '')]
# [('buy', '')]
# []
# []
# ...

# %%
len([x for x in rc_list if x != ''])
# Out:
# 2

# %%
rc['Summary'].iloc[0]
# Out:
# 'We rebuild our EQT model following the transfer of lead coverage and refresh our investment case. We remain constructive on the outlook for EQT, given strong investment performance and faster growth vs peers supported by the acquisition of BPEA, which we think has strong strategic rationale (even if not cheap). EQT has de-rated heavily YTD, however we still see several reasons that make it relatively more exposed to further macro/market deterioration vs peers. With the shares now trading on c20x 2023E/24E EPS, we now see valuation as fairer and so upgrade our rating to Neutral. By contrast, in an uncertain market environment, we prefer to position more defensively with names that are more diversified and less geared to performance fees. Our Top Pick in the space is ICP, which is far more diversified, has solid mgmt. fee revenue growth, and yet trades on a single-digit FRE multiple.'

# %%
senti['rating_curr'] = ''
senti.loc[rc_mask, 'rating_curr'] = rc_list

# %%
DL.toDB(senti, 'Citi sentiment.csv')

# %%
senti
# Out:
#                       Time                                            Summary  \
# 0      2022-05-10 12:22:00  HIMS exceeded our/cons. estimates across the b...
# 1      2022-05-10 12:00:00  European mining are currently in a phase where...
# 2      2022-05-10 11:43:00  Q1 was a slight miss, ~400MW of solar timeline...
# 3      2022-05-10 11:43:00  COTY put up another strong quarter with fiscal...
# 4      2022-05-10 11:15:00  We caught up with Arcus mgmt post-close and ob...
# ...                    ...                                                ...
# 66394  2017-03-02 15:36:00  Citi's Take - Standard Bank reported diluted H...
# 66395  2017-03-02 13:46:00  Why not a Buy? - The share has bounced c20% fr...
# 66396  2017-03-02 12:00:00  We view the FY16 result as a strong underlying...
# 66397  2017-03-01 15:01:00  Regulator approves offer of 25% of Vodacom Tan...
# 66398  2017-03-01 13:05:00  Closer inspection of Bidvest's interim results...
#
# ...

# %%
senti = DL.loadDB('Citi sentiment.csv')
# Out:
# 16:21:58 Loading C:/Users/JayYang/OneDrive - Alpha Sherpa Capital/Database/Citi\Citi sentiment.csv

# %%
senti['rating_prev'].replace(0, np.nan)
# senti[senti['Ticker'] == 'EXPN.L']
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 66975          0
# 66976    neutral
# 66977        NaN
# 66978          0
# 66979        NaN
# Name: rating_prev, Length: 66980, dtype: object
